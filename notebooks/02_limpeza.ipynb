# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from src.clean import load_data, clean_data

df = load_data("../data/raw/BASE DE DADOS PEDE 2024 - DATATHON.xlsx")
df = clean_data(df)

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("º", "n")
    .str.replace("ç", "c")
    .str.replace("ã", "a")
    .str.replace("ê", "e")
)

df.columns

# %%
df.to_parquet("../data/processed/pede.parquet")
